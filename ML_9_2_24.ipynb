# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhuriganji/AI_ML_Avanthi_Madhuri/blob/main/ML_9_2_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
stats=np.array([16,6,21,5.5,6.7,8.9])
np.min(stats)
# Out:
# 5.5

# %%
np.max(stats)
# Out:
# 21.0

# %%
a=np.array([16,6,21,5.5,6.7,8.9])(len(a)/2)
mean=(a[0]+a[1]+a[2]+a[3]+a[4]+a[5])/len(a)
print(mean)
median=((len(a)/2)+(len(a)/2+1))/2
print(median)
# Out:
# 10.683333333333335
# 3.5

# %%
np.mean(a)
# Out:
# 10.683333333333335

# %%
np.median(a)
# Out:
# 7.800000000000001

# %%
from scipy import stats
x=stats.mode(a)
print(x)
# Out:
# ModeResult(mode=5.5, count=1)

# %%
np.std(a)
# Out:
# 5.810168289779183

# %%
np.var(a)
# Out:
# 33.75805555555555

# %% [markdown]
# 1.  **SIMPLE LINEAR REGRESSION**
#     DEPENDENT AND INDEPENDENT VARIABLE
# 2.  POSITIVE AND NEGATIVE SLOPED LINEAR REGRESSION LINES

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('/content/canada_per_capita_income.csv')
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
#create linear regression object
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('per capita income(US$)')
plt.scatter(df['year'],df['per capita income (US$)'],color='red',marker='.')

# %%
x = df.drop('per capita income (US$)',axis='columns')
x
# Out:
#     year
# 0   1970
# 1   1971
# 2   1972
# 3   1973
# 4   1974
# 5   1975
# 6   1976
# 7   1977
# 8   1978
# 9   1979
# 10  1980
# 11  1981
# 12  1982
# 13  1983
# 14  1984
# 15  1985
# 16  1986
# 17  1987
# 18  1988
# 19  1989
# 20  1990
# 21  1991
# 22  1992
# 23  1993
# 24  1994
# 25  1995
# 26  1996
# 27  1997
# 28  1998
# 29  1999
# 30  2000
# 31  2001
# 32  2002
# 33  2003
# 34  2004
# 35  2005
# 36  2006
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016

# %%
y= df['per capita income (US$)']
y
# Out:
# 0      3399.299037
# 1      3768.297935
# 2      4251.175484
# 3      4804.463248
# 4      5576.514583
# 5      5998.144346
# 6      7062.131392
# 7      7100.126170
# 8      7247.967035
# 9      7602.912681
# 10     8355.968120
# 11     9434.390652
# 12     9619.438377
# 13    10416.536590
# 14    10790.328720
# 15    11018.955850
# 16    11482.891530
# 17    12974.806620
# 18    15080.283450
# 19    16426.725480
# 20    16838.673200
# 21    17266.097690
# 22    16412.083090
# 23    15875.586730
# 24    15755.820270
# 25    16369.317250
# 26    16699.826680
# 27    17310.757750
# 28    16622.671870
# 29    17581.024140
# 30    18987.382410
# 31    18601.397240
# 32    19232.175560
# 33    22739.426280
# 34    25719.147150
# 35    29198.055690
# 36    32738.262900
# 37    36144.481220
# 38    37446.486090
# 39    32755.176820
# 40    38420.522890
# 41    42334.711210
# 42    42665.255970
# 43    42676.468370
# 44    41039.893600
# 45    35175.188980
# 46    34229.193630
# ...

# %%
model.fit(x , y)
# Out:
# LinearRegression()

# %%
model.predict([[2024]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([44602.55439531])

# %%
model.score(x,y)
# Out:
# 0.890916917957032

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('prices')
plt.scatter(df.area,df.prices,color='red',marker='+')
plt.plot(d.area,model.predict(d[['area']]),color='blue')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-70d808604067> in <cell line: 4>()
#       2 plt.xlabel('area')
#       3 plt.ylabel('prices')
# ----> 4 plt.scatter(df.area,df.prices,color='red',marker='+')
#       5 plt.plot(d.area,model.predict(d[['area']]),color='blue')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'area'
